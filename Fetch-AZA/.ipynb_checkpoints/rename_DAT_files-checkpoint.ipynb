# %%
import os
import re
import glob

# %%
dat_dir=os.path.join('c:/Users','Public','Documents','Sonardyne','Subsea Array Manager','CE_SEABED_COMMS','Data','007C14')
flist=glob.glob(dat_dir+'/*.DAT')

flist

for i in flist:
    fparts=os.path.splitext(os.path.basename(i))
    fname=fparts[0]
    fnamesplit=fname.split('_')[:-1]
    newfname=fnamesplit[0]+'_'+fnamesplit[1]+'_'+'007C14'+'_'+fnamesplit[2]+'_'+fnamesplit[3]+'_'+fnamesplit[4]+'_.dat'
    os.rename(i, os.path.join('c:/Users','Public','Documents','Sonardyne','Subsea Array Manager','CE_SEABED_COMMS','Data',newfname))
