# %%
import pandas as pd
import os

# %%
file=os.path.join('x:/Marphys_Archive','Data','OSNAP','RHADCP','RHADCP_S55_data_JC238','converted','S200044A008_RHADCP_2020A0_avgd.csv')
# file=os.path.join('e:','osnap','JC238','Sensors_and_Moorings','Sensors_and_Moorings','Moorings','Recovery','RHADCP','RHADCP_S55_data_JC238','S200044A008_RHADCP_2020','S200044A008_RHADCP_2020_avgd.AD2CP')
file
# Out:
# 'x:/Marphys_Archive\\Data\\OSNAP\\RHADCP\\RHADCP_S55_data_JC238\\converted\\S200044A008_RHADCP_2020A0_avgd.csv'

# %%
df=pd.read_csv(file,sep=';')

# %%
df
# Out:
#                   DateTime  EnsembleCount  Battery    Heading      Pitch  \
# 0      10/15/2020 11:30:01              1     18.1   91.49700 -23.722010
# 1      10/15/2020 12:00:01              1     18.1   97.51301 -26.082000
# 2      10/15/2020 12:30:01              1     18.1  150.76830 -85.287010
# 3      10/15/2020 13:00:01              1     18.1  137.46010 -86.015010
# 4      10/15/2020 13:30:01              1     18.0  146.74770 -86.017980
# ...                    ...            ...      ...        ...        ...
# 30858  07/20/2022 08:30:01              1     17.5  328.94300  -1.076000
# 30859  07/20/2022 09:00:01              1     17.4  328.83200  -0.977000
# 30860  07/20/2022 09:30:01              1     17.4  329.07700  -0.776000
# 30861  07/20/2022 10:00:01              1     17.4   21.09041  -0.347089
# 30862  07/20/2022 10:30:01              1     17.5  300.38530 -15.394000
#
#            Roll   Pressure  Temperature  East#1  North#1  ...  Corr3#53  \
# 0     -45.41000     0.6441       14.474 -0.2725  -0.1920  ...        12
# 1     -41.25697     0.6162       14.454  0.0492  -0.0024  ...        10
# 2      12.37353     0.6339       15.260 -0.1731  -0.0360  ...         6
# 3      16.43966     0.6300       15.154 -0.0381  -0.0168  ...        13
# 4       8.69242     0.6120       14.685 -0.0139   0.0350  ...        10
# ...         ...        ...          ...     ...      ...  ...       ...
# 30858   0.86100  1077.1370        5.663  0.0544   0.1135  ...        28
# 30859   0.87800  1077.3210        5.660  0.0200   0.1559  ...        22
# 30860   0.77300  1077.4200        5.648  0.0791   0.1591  ...        25
# 30861  12.33626   306.5414        9.661  0.2082  -0.0433  ...         8
# 30862 -77.37397     0.2467       12.938 -0.0614   0.0182  ...        13
#
#        Corr1#54  Corr2#54  Corr3#54  Corr1#55  Corr2#55  Corr3#55  Corr1#56  \
# 0            10         9         6        10        10        10        12
# 1            10         9        12         9        10        10         8
# 2            10        11        11        10         7         8         9
# 3             8        10        12        11        11         9        11
# 4             8         9        10         9        10         8         8
# ...         ...       ...       ...       ...       ...       ...       ...
# 30858        18        18        21        15        14        19        12
# 30859        20        21        18        18        18        22        17
# 30860        18        18        24        15        24        10        21
# 30861         6         8         8        12         6        10         9
# 30862         8        10         9         8        11         7        14
#
#        Corr2#56  Corr3#56
# 0            12        11
# 1             8         8
# 2            12         7
# 3             9        12
# 4             9         6
# ...         ...       ...
# 30858        12        15
# 30859        16        18
# 30860        18        12
# 30861         7        11
# 30862         9         9
#
# [30863 rows x 512 columns]
