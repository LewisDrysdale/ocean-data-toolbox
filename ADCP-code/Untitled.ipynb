# %%
import pandas as pd
import os

# %%
file=os.path.join('x:/Marphys_Archive','Data','OSNAP','RHADCP','RHADCP_S55_data_JC238','converted','S200044A008_RHADCP_2020A0_avgd.csv')
# file=os.path.join('e:','osnap','JC238','Sensors_and_Moorings','Sensors_and_Moorings','Moorings','Recovery','RHADCP','RHADCP_S55_data_JC238','S200044A008_RHADCP_2020','S200044A008_RHADCP_2020_avgd.AD2CP')
file
# Out:
# 'x:/Marphys_Archive\\Data\\OSNAP\\RHADCP\\RHADCP_S55_data_JC238\\converted\\S200044A008_RHADCP_2020A0_avgd.csv'

# %%
df=pd.read_csv(file,sep=';')

# %%
list(df)
# Out:
# ['DateTime',
#  'EnsembleCount',
#  'Battery',
#  'Heading',
#  'Pitch',
#  'Roll',
#  'Pressure',
#  'Temperature',
#  'East#1',
#  'North#1',
#  'Up#1',
#  'East#2',
#  'North#2',
#  'Up#2',
#  'East#3',
#  'North#3',
#  'Up#3',
#  'East#4',
#  'North#4',
#  'Up#4',
#  'East#5',
#  'North#5',
#  'Up#5',
#  'East#6',
#  'North#6',
#  'Up#6',
#  'East#7',
#  'North#7',
#  'Up#7',
#  'East#8',
#  'North#8',
#  'Up#8',
#  'East#9',
#  'North#9',
#  'Up#9',
#  'East#10',
#  'North#10',
#  'Up#10',
#  'East#11',
#  'North#11',
#  'Up#11',
#  'East#12',
#  'North#12',
#  'Up#12',
#  'East#13',
#  'North#13',
#  'Up#13',
#  'East#14',
#  'North#14',
#  'Up#14',
#  'East#15',
#  'North#15',
#  'Up#15',
#  'East#16',
#  'North#16',
#  'Up#16',
#  'East#17',
#  'North#17',
#  'Up#17',
#  'East#18',
#  'North#18',
#  'Up#18',
#  'East#19',
#  'North#19',
#  'Up#19',
#  'East#20',
#  'North#20',
#  'Up#20',
#  'East#21',
#  'North#21',
#  'Up#21',
#  'East#22',
#  'North#22',
#  'Up#22',
# ...
